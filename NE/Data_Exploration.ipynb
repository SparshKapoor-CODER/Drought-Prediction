# %%
import pandas as pd

# %%
df = pd.read_csv('data_NE\pair_1_2001_2005_to_2006_2010.csv')
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\Dell\AppData\Local\Temp\ipykernel_6652\3255982061.py:1: SyntaxWarning: invalid escape sequence '\p'
#   df = pd.read_csv('data_NE\pair_1_2001_2005_to_2006_2010.csv')
#    system:index  loss_label  past_loss  rainfall_anomaly  rainfall_total  \
# 0             0           1          0       1406.292159    11466.173206
# 1             1           0          0       1309.242957    12575.646368
# 2             2           0          0       2298.527793    16032.454336
# 3             6           0          0       1498.822905    14589.982834
# 4            10           0          0        583.675904     7704.975117
#
#         spi  treecover2000                                               .geo
# 0  0.681355             32  {"type":"Point","coordinates":[92.410081655011...
# 1  0.484411             60  {"type":"Point","coordinates":[92.857240164650...
# ...

# %%
df.columns
# Out:
# Index(['system:index', 'loss_label', 'past_loss', 'rainfall_anomaly',
#        'rainfall_total', 'spi', 'treecover2000', '.geo'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# system:index        0
# loss_label          0
# past_loss           0
# rainfall_anomaly    0
# rainfall_total      0
# spi                 0
# treecover2000       0
# .geo                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# system:index          int64
# loss_label            int64
# past_loss             int64
# rainfall_anomaly    float64
# rainfall_total      float64
# spi                 float64
# treecover2000         int64
# .geo                 object
# dtype: object

# %%
df.describe()
# Out:
#        system:index   loss_label    past_loss  rainfall_anomaly  \
# count   2715.000000  2715.000000  2715.000000       2715.000000
# mean    2491.916759     0.158748     0.025046       1479.326907
# std     1441.395135     0.365508     0.156294        555.489984
# min        0.000000     0.000000     0.000000        110.344061
# 25%     1229.500000     0.000000     0.000000       1056.389255
# 50%     2486.000000     0.000000     0.000000       1392.104751
# 75%     3729.500000     0.000000     0.000000       1858.971726
# max     4998.000000     1.000000     1.000000       3413.271345
#
#        rainfall_total          spi  treecover2000
# count     2715.000000  2715.000000    2715.000000
# mean     12148.957453     0.635762      68.749171
# std       3393.087808     0.153230      18.290461
# min       1748.132816     0.082713      25.000000
# 25%       9755.010791     0.540769      56.500000
# 50%      12048.509745     0.633386      73.000000
# ...

# %%
df.shape
# Out:
# (2715, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2715 entries, 0 to 2714
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   system:index      2715 non-null   int64
#  1   loss_label        2715 non-null   int64
#  2   past_loss         2715 non-null   int64
#  3   rainfall_anomaly  2715 non-null   float64
#  4   rainfall_total    2715 non-null   float64
#  5   spi               2715 non-null   float64
#  6   treecover2000     2715 non-null   int64
#  7   .geo              2715 non-null   object
# dtypes: float64(3), int64(4), object(1)
# memory usage: 169.8+ KB
